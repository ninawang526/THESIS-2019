# %% [markdown]
# # Comparing consistency across different news outlets, over time

# %%
import pickle
import datetime

import THESIS2019.utils.to_lexicon as lex
from THESIS2019.utils.base_words import *
import THESIS2019.utils.get_articles as get

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

from collections import defaultdict

from importlib import reload

import dit
from dit.divergences import jensen_shannon_divergence

from palmettopy.palmetto import Palmetto

# %%
def pickle_dump(outlet, articles, dictionary, corpus, model):
    with open(outlet+"_model2012.pkl","wb") as f:
        pickle.dump(model, f)
    with open(outlet+"_articles2012.pkl","wb") as f:
        pickle.dump(articles, f)
    with open(outlet+"_dictionary2012.pkl","wb") as f:
        pickle.dump(dictionary, f)
    with open(outlet+"_corpus2012.pkl","wb") as f:
        pickle.dump(corpus, f)
        
def pickle_load(outlet):
    with open(outlet+"_model2012.pkl","rb") as f:
        model = pickle.load(f)
    with open(outlet+"_dictionary2012.pkl","rb") as f:
        dictionary = pickle.load(f)
    with open(outlet+"_articles2012.pkl","rb") as f:
        articles = pickle.load(f)
    with open(outlet+"_corpus2012.pkl","rb") as f:
        corpus = pickle.load(f)
    return articles, dictionary, corpus, model
    

def get_lda_models(article_set, load=True, store=False):
    arts_list, dictionary_list, corpus_list, model_list = defaultdict(lambda:0),defaultdict(lambda:0),defaultdict(lambda:0),defaultdict(lambda:0)
    
    for outlet, articles in article_set.items():
        print("%s has %d articles" %(outlet, len(articles)))
        
        if load:
            arts, dictionary, corpus, model = pickle_load(outlet)
        else:
            art_set = {outlet:articles}
            arts, dictionary, corpus, model = lex.LDA(art_set, LEFT_WORDS+RIGHT_WORDS,num_topics=30)
            if store:
                pickle_dump(outlet, arts, dictionary, corpus, model)
        
        arts_list[outlet]=arts
        dictionary_list[outlet]=dictionary
        corpus_list[outlet]=corpus
        model_list[outlet]=model
        
    return arts_list, dictionary_list, corpus_list, model_list

# %%
# notebook to find consistency over time of topic models using LDA
reload(get)

datapath = "/Users/ninawang/Thesis/remote/THESIS2019/example_data_1000/"
# outlets = ['BREITBART','NATIONALREVIEW','FOX',
#              'WASHINGTONEXAMINER','REUTERS','NPR',
#              'NYT', 'MSN','CNN','SLATE']
outlets = ['BREITBART']
articles = get.get_articles_outlets(datapath,outlets,2012,filter_date=False)

for outlet, article in articles.items():
    print("%s has %d articles" %(outlet, len(article)))
# Out:
# BREITBART2012-2013 has 960 articles
# CNN2012-2013 has 825 articles

# %%
reload(lex)
arts_list, dictionary_list, corpus_list, model_list = get_lda_models(articles, load=False, store=False)

# print (corpus_list["BREITBART2012-2013"][0])
# Out:
# BREITBART2012-2013 has 960 articles
# getting docs...
# --- 58.944167375564575 seconds ---
# getting LDA model...
# --- 121.88135480880737 seconds ---
# CNN2012-2013 has 825 articles
# getting docs...
# --- 68.07620525360107 seconds ---
# getting LDA model...
# --- 191.64171600341797 seconds ---

# %%
from gensim import corpora
from gensim.models.coherencemodel import CoherenceModel
import itertools

texts = list(arts_list['BREITBART2012-2013'].values())[0]+list(arts_list['CNN2012-2013'].values())[0]
text_dictionary = corpora.Dictionary(texts)
print(text_dictionary)
text_corpus = [dictionary.doc2bow(text) for text in texts]

cm = CoherenceModel(topics=[["american","polici"],["chang","world"]],texts=texts, corpus=text_corpus, dictionary=text_dictionary, coherence='c_npmi')
coherence = cm.get_coherence()
print(coherence)
# Out:
# Dictionary(16710 unique tokens: ['administr', 'african', 'ago', 'aim', 'alli']...)
# 0.025221935669721512

# %%
def pmi(wordslist, texts, corpus, dictionary):
    cm = CoherenceModel(topics=wordslist,texts=texts, corpus=corpus, dictionary=dictionary, coherence='c_npmi')
    return cm.get_coherence()

# %%
import nltk

def print_topics(model):
    topics = model.show_topics(num_topics=-1, num_words=5, log=False, formatted=False)
    for idx, topic in topics:
        print ("topic " + str(idx) + ": " + (",  ").join([str(t[0]) for t in topic]))
    
    
def pairwise_compare_outlets(model1, model2, numtopics=30):
    first0 = model1.show_topic(topicid=0,topn=10)
    second0 = model2.show_topic(topicid=0,topn=10)
    print(first0)
    print(second0)
    scores = []
    for w1,p1 in first0:
        for w2, p2 in second0:
            score = PMI(w1,w2)
        
# get ngrams/bigrams
# combined bow
nytdict = dictionary_list["CNN2012-2013"]
print(nytdict)
print(arts_list)
for bow in arts_list["CNN2012-2013"]:
    for ind,c in bow:
        print
# all_articles = [nltk.word_tokenize(article.text) for articles in articles.values() for article in articles]


unigrams = nltk.FreqDist(all_articles)
bigrams = ngrams(ListA,2)

n1_freq = nltk.FreqDist(unigrams)
n2_freq = nltk.FreqDist(bigrams)
        
outlet_list = list(articles.keys())
sample_outlet_list = [outlet_list[0],outlet_list[-2]]
compare = []
for outlet in sample_outlet_list:
    oarts = arts_list[outlet]
    odictionary = dictionary_list[outlet]
    ocorpus = corpus_list[outlet]
    omodel = model_list[outlet]
    compare.append(omodel)
#     print(outlet)
# #     print_topics(omodel)
#     print(omodel.show_topic(topicid=0,topn=5))
#     print()

# first, combine similar topics...

# pairwise_compare_outlets(compare[0],compare[1])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-386763f9b616> in <module>
#      23 print(arts_list)
#      24 for bow in arts_list["CNN2012-2013"]:
# ---> 25     for ind,c in bow:
#      26         print
#      27 # all_articles = [nltk.word_tokenize(article.text) for articles in articles.values() for article in articles]
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
# select document
def to_words(bow):
    wds = []
    for idx,c in bow:
        wds.append(dictionary[idx])
    return wds
        
topicn = 4
print(arts)

print(arts[topicn])
print(arts)
print()

print(model[corpus[topicn]])
# Out:
# {'NYT-OPINION2012-2013': [<NewsArticle.NewsArticle object at 0x108fc35f8>, <NewsArticle.NewsArticle object at 0x108fc38d0>, <NewsArticle.NewsArticle object at 0x108fc3828>, <NewsArticle.NewsArticle object at 0x11ca915f8>, <NewsArticle.NewsArticle object at 0x11ca915c0>, <NewsArticle.NewsArticle object at 0x11ca91710>, <NewsArticle.NewsArticle object at 0x11ca91860>, <NewsArticle.NewsArticle object at 0x11ca917b8>, <NewsArticle.NewsArticle object at 0x11ca91
<NewsArticle.NewsArticle object at 0x11caa4cf8>, <NewsArticle.NewsArticle object at 0x11caa4ef0>, <NewsArticle.NewsArticle object at 0x11caa71d0>, <NewsArticle.NewsArticle object at 0x11caa7470>, <NewsArticle.NewsArticle object at 0x11caa7518>, <NewsArticle.NewsArticle object at 0x11caa75c0>, <NewsArticle.NewsArticle object at 0x11caa76d8>, <NewsArticle.NewsArticle object at 0x11caa7cc0>, <NewsArticle.NewsArticle object at 0x11caa7588>, <NewsArticle.NewsArticle object at 0x11caa7f98>, <NewsArticle.NewsArticle object at 0x11caa7fd0>, <NewsArticle.NewsArticle object at 0x11caaa518>, <NewsArticle.NewsArticle object at 0x11caaa668>, <NewsArticle.NewsArticle object at 0x11caaa8d0>, <NewsArticle.NewsArticle object at 0x11caaa898>, <NewsArticle.NewsArticle object at 0x11caaaba8>, <NewsArticle.NewsArticle object at 0x11caaacf8>, <NewsArticle.NewsArticle object at 0x11caaaf98>, <News ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-b984a8f72dfd> in <module>
#       9 print(arts)
#      10
# ---> 11 print(arts[topicn])
#      12 print(arts)
#      13 print()
#
# KeyError: 4

# %%
# aggregate topic distribution for a document set
from collections import defaultdict

# total topic distribution for a document set
def total_topic_distribution(model, corpus):
    dist = defaultdict(lambda:0)
    for doc in corpus:
        topics = model[doc]
        for topic,prob in topics:
            dist[topic] += prob  
    # normalize - turn into percentage of total
    s = sum(dist.values())
    for d in dist:
        dist[d] /= s
    return dist

def graph_distribution(dist, title):
    x, y = dist.keys(), dist.values()
    plt.bar(x, y, alpha=0.5)
    plt.xlabel('Topic number')
    plt.ylabel('Proportion in document set')
    plt.title('Topic distribution for %s' %(title))

    plt.show()

        
dist = total_topic_distribution(model, corpus)
graph_distribution(dist, "sample")

# %%
dist_list = [(k,v) for k,v in dist.items()]
sorted_dist = sorted(dist_list, key=lambda x:x[1],reverse=True)
print (sorted_dist)
# Out:
# [(3, 0.12057011472143349), (6, 0.10180328037361183), (20, 0.07265982030215559), (15, 0.05614413939311899), (2, 0.05572603585335182), (16, 0.048612916089727114), (19, 0.046903144958807604), (5, 0.043378270346374884), (22, 0.0400816801947363), (29, 0.03698104030501667), (9, 0.033102968803144533), (27, 0.03235101411668727), (28, 0.03112312485582843), (26, 0.030581951298248033), (10, 0.029432236598144836), (7, 0.02586944952838725), (18, 0.02325329132843771), (14, 0.02313060297401259), (0, 0.020237504317128674), (8, 0.018615967180115753), (11, 0.018346174174724342), (24, 0.018114289993058565), (12, 0.01562938259270455), (1, 0.01376627838392221), (23, 0.012182630168106922), (4, 0.010638620488753126), (17, 0.008395070520637551), (13, 0.0055912556723215195), (25, 0.004671083538263978), (21, 0.002106660929037869)]

# %%
# arts = {"2012":[],"2013":[]}
# for i,article in enumerate(articles):
#     if article.date_publish is not None:
#         arts[str(article.date_publish.year)].append(corpus[i])

def to_distro(dist):
    ids, probs = list(dist.keys()), list(dist.values())
    distro = dit.ScalarDistribution(ids, probs)
    return distro

# def compare_topic_distributions(d1, d2):
#     X, Y = to_distro(d1), to_distro(d2)
#     return jensen_shannon_divergence([X,Y])

# %%
print(articles.keys())
# Out:
# dict_keys(['BREITBART2012-2013', 'NATIONALREVIEW2012-2013', 'FOX2012-2013', 'WASHINGTONEXAMINER2012-2013', 'REUTERS2012-2013', 'NPR2012-2013', 'NYT2012-2013', 'MSN2012-2013', 'CNN2012-2013', 'SLATE2012-2013'])

# %%
from THESIS2019.PART1.TopicModel.LDA import lda_consistency as ldac
reload(ldac)

bowarts = {}
for key, articleset in articles.items():
    for i,article in enumerate(articleset):
        if key not in bowarts:
            bowarts[key]=[corpus[i]]
        else:
            bowarts[key].append(corpus[i])

distros=[]
for key,articleset in bowarts.items():
    print(key,len(articleset))
    distro = total_topic_distribution(model, articleset)
    distros.append(distro)
    graph_distribution(distro, key)
    

# jsd = compare_topic_distributions(dist2012, dist2013)
jsd = ldac.compare_topic_distributions(distros)
print("JS Divergence of topic: %f"%(jsd))
# Out:
# BREITBART2012-2013 960
# defaultdict(<function total_topic_distribution.<locals>.<lambda> at 0x12afdba60>, {5: 53.94617575779557, 16: 155.965064028278, 26: 34.36708202213049, 28: 38.622139726765454, 29: 39.8439151737839, 0: 8.978326224721968, 9: 27.16909626778215, 10: 48.754804292693734, 20: 41.887747841887176, 22: 34.245151116512716, 7: 17.600147078745067, 14: 11.863684189505875, 15: 126.01257260516286, 8: 35.01438420917839, 11: 14.959644892252982, 2: 11.382846180349588, 1: 4.31047201436013, 27: 25.292932664975524, 24: 10.595619312487543, 4: 9.164367937482893, 12: 10.833618502132595, 17: 6.3273802399635315, 3: 118.51415385864675, 19: 18.752647454850376, 23: 4.914150070399046, 18: 12.578539640642703, 6: 24.179384385235608, 13: 2.8932221280410886, 25: 2.759448773227632, 21: 2.788857748731971})
# NATIONALREVIEW2012-2013 986
# defaultdict(<function total_topic_distribution.<locals>.<lambda> at 0x12ace06a8>, {5: 54.3809933392331, 16: 157.73829089198261, 26: 35.23183063138276, 28: 39.45672754198313, 29: 42.16286168806255, 0: 9.00316658243537, 9: 27.74625854473561, 10: 51.995841247960925, 20: 43.14701158646494, 22: 35.20817936398089, 7: 18.16816266719252, 14: 11.843800472095609, 15: 127.07021850626916, 8: 35.99156747572124, 11: 14.974589488469064, 2: 12.031842128373682, 1: 4.442632796242833, 27: 26.346199461258948, 24: 10.995229290798306, 4: 9.37648271676153, 12: 11.060948241502047, 17: 6.3553218068555, 3: 124.11865392327309, 19: 19.005752549506724, 23: 4.914169257506728, 18: 12.646173351444304, 6: 26.030099067837, 13: 3.3112326599657536, 25: 2.875035708770156, 21: 2.7889844784513116})
# FOX2012-2013 991
# defaultdict(<function total_topic_distribution.<locals>.<lambda> at 0
# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')

# %%
import pandas as pd

# ordered_outlets = ['BREITBART2012-2013','NATIONALREVIEW2012-2013','FOX2012-2013',
#              'WASHINGTONEXAMINER2012-2013','REUTERS-POLITICS2012-2013','NPR2012-2013',
#              'NYT-OPINION2012-2013', 'MSN2012-2013','CNN2012-2013','SLATE2012-2013']
ordered_outlets = ['BREITBART2012-2013','NATIONALREVIEW2012-2013','FOX2012-2013',
             'WASHINGTONEXAMINER2012-2013','NPR2012-2013',
             'NYT-OPINION2012-2013', 'MSN2012-2013','CNN2012-2013']

dist_by_outlet=defaultdict(lambda:0)
for outlet in ordered_outlets:
    articleset=bowarts[outlet]
    print(outlet,len(articleset))
    dist = total_topic_distribution(model, articleset)
    dist_by_outlet[outlet]=dist

# NYT-OPINION2012-2013 275
# BREITBART2012-2013 281
# CNN2012-2013 149
# FOX2012-2013 300
# MSN2012-2013 293
# NATIONALREVIEW2012-2013 289
# NPR2012-2013 280
# REUTERS-POLITICS2012-2013 125
# SLATE2012-2013 131
# WASHINGTONEXAMINER2012-2013 286
# Out:
# BREITBART2012-2013 960
# NATIONALREVIEW2012-2013 986
# FOX2012-2013 991
# WASHINGTONEXAMINER2012-2013 949
# NPR2012-2013 920
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-a3bdbe475004> in <module>
#      10 dist_by_outlet=defaultdict(lambda:0)
#      11 for outlet in ordered_outlets:
# ---> 12     articleset=bowarts[outlet]
#      13     print(outlet,len(articleset))
#      14     dist = total_topic_distribution(model, articleset)
#
# KeyError: 'NYT-OPINION2012-2013'

# %%
# to pd
df = pd.DataFrame(dist_by_outlet)

# %%
df
# Out:
#     BREITBART2012-2013  NATIONALREVIEW2012-2013  FOX2012-2013  \
# 0             0.076547                 0.075227      0.075788
# 1             0.010399                 0.010404      0.010128
# 2             0.007336                 0.007142      0.006878
# 3             0.027604                 0.027338      0.028711
# 4             0.067540                 0.065971      0.064711
# 5             0.011581                 0.013262      0.012776
# 6             0.015182                 0.015374      0.018779
# 7             0.079991                 0.078298      0.076975
# 8             0.003764                 0.003660      0.003560
# 9             0.010062                 0.009780      0.009620
# 10            0.281094                 0.280811      0.282675
# 11            0.024009                 0.023868      0.024323
# 12            0.002280                 0.002217      0.002135
# 13            0.008638                 0.009280      0.008939
# 14            0.022248                 0.021630      0.020834
# 15            0.059286                 0.057640      0.055518
# 16            0.022560                 0.022567      0.022295
# 17            0.008878                 0.008909      0.009344
# 18            0.009245                 0.012883      0.017515
# 19            0.006156                 0.005985      0.005765
# 20            0.001880                 0.001828      0.001762
# 21            0.027639                 0.032722      0.031519
# 22            0.088940                 0.086828      0.085165
# 23            0.018518                 0.018005      0.017919
# 24            0.000869                 0.001013      0.000975
# 25            0.008343                 0.008114      0.007820
# 26            0.016383                 0.015928      0.015342
# 27            0.036351                 0.036944      0.036689
# 28            0.027055                 0.027298      0.026299
# 29            0.019620                 0.019076      0.019243
#
#     WASHINGTONEXAMINER2012-2013  NPR2012-2013  NYT-OPINION2012-2013  \
# 0                      0.075842      0.076829              0.078244
# 1                      0.010212      0.010433              0.010625
# 2                      0.007208      0.007365              0.007502
# 3                      0.027235      0.025737              0.026154
# 4                      0.066666      0.067783              0.069016
# 5                      0.011381      0.011625              0.011838
# 6                      0.015023      0.014065              0.014238
# 7                      0.078810      0.080276              0.074711
# 8                      0.003698      0.003778              0.003846
# 9                      0.009882      0.010097              0.010278
# 10                     0.282398      0.282088              0.276194
# 11                     0.024008      0.024095              0.024534
# 12                     0.002240      0.002288              0.002324
# 13                     0.009378      0.008669              0.008824
# 14                     0.021857      0.022327              0.022676
# 15                     0.058244      0.059496              0.060576
# 16                     0.022808      0.022645              0.023115
# 17                     0.008723      0.008910              0.009071
# 18                     0.009448      0.008928              0.009090
# 19                     0.006048      0.006178              0.006290
# 20                     0.001847      0.001886              0.001921
# 21                     0.033068      0.027739              0.028242
# 22                     0.087568      0.089264              0.090883
# 23                     0.018193      0.018583              0.018922
# 24                     0.001023      0.000872              0.000888
# 25                     0.008197      0.008373              0.008527
# 26                     0.016096      0.016442              0.016740
# 27                     0.036029      0.036382              0.037040
# 28                     0.027593      0.027152              0.027642
# 29                     0.019278      0.019692              0.020049
#
#     MSN2012-2013  CNN2012-2013
# 0       0.077582      0.112020
# 1       0.010255      0.009639
# 2       0.007037      0.011640
# 3       0.027535      0.022261
# 4       0.065067      0.023411
# 5       0.013083      0.007621
# 6       0.016203      0.012265
# 7       0.077471      0.038779
# 8       0.003610      0.005706
# 9       0.009658      0.013863
# 10      0.280362      0.429310
# 11      0.024009      0.039132
# 12      0.002186      0.004038
# 13      0.009152      0.013427
# 14      0.021333      0.023461
# 15      0.056846      0.018358
# 16      0.022712      0.038460
# 17      0.008787      0.005475
# 18      0.016853      0.007652
# 19      0.005903      0.003082
# 20      0.001801      0.002844
# 21      0.032273      0.022259
# 22      0.085638      0.048757
# 23      0.017756      0.021371
# 24      0.000999      0.001211
# 25      0.007995      0.008696
# 26      0.015710      0.007138
# 27      0.036438      0.024057
# 28      0.026930      0.017087
# 29      0.018815      0.006977

# %%
df=df.T

# %%
# multiple line plot
num=0
for column in df:
    num+=1
 
    # Find the right spot on the plot
    plt.subplot(4,4, num)
 
    # Plot the lineplot
    x = df.index.values
    plt.plot(x, df[column], marker='', color=palette(num), linewidth=1.9, alpha=0.9, label=column)
 
    # Same limits for everybody!
#     plt.xlim(0,30)
    plt.ylim(-.1,.15)
 
    # Not ticks everywhere
#     if num in range(7) :
#         plt.tick_params(labelbottom='off')
#     if num not in [1,4,7] :
#         plt.tick_params(labelleft='off')
 
    # Add title
    plt.title(column, loc='left', fontsize=12, fontweight=0, color=palette(num) )
    
    if num==16:
        break
